# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("index_1.csv")

# %%
df.head(20)
# Out:
#           date                 datetime cash_type                 card  money  \
# 0   2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1   2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2   2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3   2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4   2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
# 5   2024-03-01  2024-03-01 15:39:47.726      card  ANON-0000-0000-0005   33.8
# 6   2024-03-01  2024-03-01 16:19:02.756      card  ANON-0000-0000-0006   38.7
# 7   2024-03-01  2024-03-01 18:39:03.580      card  ANON-0000-0000-0007   33.8
# 8   2024-03-01  2024-03-01 19:22:01.762      card  ANON-0000-0000-0008   38.7
# 9   2024-03-01  2024-03-01 19:23:15.887      card  ANON-0000-0000-0008   33.8
# 10  2024-03-01  2024-03-01 19:29:17.391      card  ANON-0000-0000-0009   33.8
# ...

# %%
df.describe()
# Out:
#              money
# count  3636.000000
# mean     31.746859
# std       4.919926
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      40.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   object
#  1   datetime     3636 non-null   object
#  2   cash_type    3636 non-null   object
#  3   card         3547 non-null   object
#  4   money        3636 non-null   float64
#  5   coffee_name  3636 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 170.6+ KB

# %%
df.shape
# Out:
# (3636, 6)

# %%
df.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleaning

# %%
clean_df = df.copy()

# %%
clean_df["card"] = clean_df["card"].fillna("Cash Payment")
clean_df["coffee_name"] = clean_df["coffee_name"].str.strip()

# %%
df.duplicated(subset=["card" , "datetime"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3631    False
# 3632    False
# 3633    False
# 3634    False
# 3635    False
# Length: 3636, dtype: bool

# %%
df.tail(20)
# Out:
#             date                 datetime cash_type                 card  \
# 3616  2025-03-21  2025-03-21 18:52:12.666      card  ANON-0000-0000-0507
# 3617  2025-03-21  2025-03-21 18:59:24.271      card  ANON-0000-0000-1170
# 3618  2025-03-22  2025-03-22 09:05:13.059      card  ANON-0000-0000-1274
# 3619  2025-03-22  2025-03-22 10:30:09.403      card  ANON-0000-0000-1152
# 3620  2025-03-22  2025-03-22 11:14:05.960      card  ANON-0000-0000-1259
# 3621  2025-03-22  2025-03-22 11:41:20.579      card  ANON-0000-0000-1279
# 3622  2025-03-22  2025-03-22 12:18:27.491      card  ANON-0000-0000-1313
# 3623  2025-03-22  2025-03-22 12:25:59.676      card  ANON-0000-0000-1306
# 3624  2025-03-22  2025-03-22 13:06:21.590      card  ANON-0000-0000-1309
# 3625  2025-03-22  2025-03-22 13:23:17.918      card  ANON-0000-0000-1267
# 3626  2025-03-22  2025-03-22 15:57:58.183      card  ANON-0000-0000-1302
# 3627  2025-03-22  2025-03-22 16:26:59.766      card  ANON-0000-0000-1274
# ...

# %%
clean_df['datetime'] = pd.to_datetime(clean_df['datetime'])
clean_df['datetime'] = pd.to_datetime(clean_df['datetime'].dt.floor('s'))

# %%
clean_df.nlargest(7, 'money')
# Out:
#           date            datetime cash_type          card  money  \
# 12  2024-03-02 2024-03-02 10:30:35      cash  Cash Payment   40.0
# 18  2024-03-03 2024-03-03 10:10:43      cash  Cash Payment   40.0
# 46  2024-03-07 2024-03-07 10:08:58      cash  Cash Payment   40.0
# 49  2024-03-07 2024-03-07 11:25:43      cash  Cash Payment   40.0
# 60  2024-03-09 2024-03-09 11:49:37      cash  Cash Payment   40.0
# 76  2024-03-10 2024-03-10 10:06:02      cash  Cash Payment   40.0
# 81  2024-03-11 2024-03-11 10:18:46      cash  Cash Payment   40.0
#
#       coffee_name
# 12          Latte
# 18          Latte
# 46          Latte
# 49          Latte
# 60  Hot Chocolate
# 76          Latte
# 81          Latte

# %%
clean_df['money'] = pd.to_numeric(clean_df['money'], errors = 'coerce')

# %%
print(df['coffee_name'].unique())
# Out:
# ['Latte' 'Hot Chocolate' 'Americano' 'Americano with Milk' 'Cocoa'
#  'Cortado' 'Espresso' 'Cappuccino']

# %%
clean_df['coffee_name'] = clean_df['coffee_name'].str.strip()

# %%
clean_df = clean_df.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
clean_df.head(20)
# Out:
#           date            datetime cash_type                 card  money  \
# 0   2024-03-01 2024-03-01 10:15:50      card  ANON-0000-0000-0001   38.7
# 1   2024-03-01 2024-03-01 12:19:22      card  ANON-0000-0000-0002   38.7
# 2   2024-03-01 2024-03-01 12:20:18      card  ANON-0000-0000-0002   38.7
# 3   2024-03-01 2024-03-01 13:46:33      card  ANON-0000-0000-0003   28.9
# 4   2024-03-01 2024-03-01 13:48:14      card  ANON-0000-0000-0004   38.7
# 5   2024-03-01 2024-03-01 15:39:47      card  ANON-0000-0000-0005   33.8
# 6   2024-03-01 2024-03-01 16:19:02      card  ANON-0000-0000-0006   38.7
# 7   2024-03-01 2024-03-01 18:39:03      card  ANON-0000-0000-0007   33.8
# 8   2024-03-01 2024-03-01 19:22:01      card  ANON-0000-0000-0008   38.7
# 9   2024-03-01 2024-03-01 19:23:15      card  ANON-0000-0000-0008   33.8
# 10  2024-03-01 2024-03-01 19:29:17      card  ANON-0000-0000-0009   33.8
# 11  2024-03-02 2024-03-02 10:22:06      card  ANON-0000-0000-0010   28.9
# ...

# %% [markdown]
# ## Date Processing

# %%
clean_df['quantity'] = 1

# %%
clean_df.tail(8)
# Out:
#             date            datetime cash_type                 card  money  \
# 3628  2025-03-22 2025-03-22 17:53:35      card  ANON-0000-0000-1274  30.86
# 3629  2025-03-22 2025-03-22 19:16:52      card  ANON-0000-0000-1314  30.86
# 3630  2025-03-23 2025-03-23 10:07:11      card  ANON-0000-0000-1196  35.76
# 3631  2025-03-23 2025-03-23 10:34:54      card  ANON-0000-0000-1158  35.76
# 3632  2025-03-23 2025-03-23 14:43:37      card  ANON-0000-0000-1315  35.76
# 3633  2025-03-23 2025-03-23 14:44:16      card  ANON-0000-0000-1315  35.76
# 3634  2025-03-23 2025-03-23 15:47:28      card  ANON-0000-0000-1316  25.96
# 3635  2025-03-23 2025-03-23 18:11:38      card  ANON-0000-0000-1275  35.76
#
#               coffee_name  quantity
# 3628  Americano with Milk         1
# 3629  Americano with Milk         1
# 3630                Latte         1
# 3631           Cappuccino         1
# 3632                Cocoa         1
# 3633                Cocoa         1
# ...

# %%
clean_df.drop("date", axis = 1 , inplace = True)
clean_df.head()
# Out:
#              datetime cash_type                 card  money    coffee_name  \
# 0 2024-03-01 10:15:50      card  ANON-0000-0000-0001   38.7          Latte
# 1 2024-03-01 12:19:22      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 2 2024-03-01 12:20:18      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 3 2024-03-01 13:46:33      card  ANON-0000-0000-0003   28.9      Americano
# 4 2024-03-01 13:48:14      card  ANON-0000-0000-0004   38.7          Latte
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
clean_df.isnull().sum()
# Out:
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# quantity       0
# dtype: int64

# %%
clean_df.to_csv('my_cleanedKaggle42_data.csv' , index=False)

# %%
clean_df.head(30)
# Out:
#               datetime cash_type                 card  money  \
# 0  2024-03-01 10:15:50      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01 12:19:22      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01 12:20:18      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01 13:46:33      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01 13:48:14      card  ANON-0000-0000-0004   38.7
# 5  2024-03-01 15:39:47      card  ANON-0000-0000-0005   33.8
# 6  2024-03-01 16:19:02      card  ANON-0000-0000-0006   38.7
# 7  2024-03-01 18:39:03      card  ANON-0000-0000-0007   33.8
# 8  2024-03-01 19:22:01      card  ANON-0000-0000-0008   38.7
# 9  2024-03-01 19:23:15      card  ANON-0000-0000-0008   33.8
# 10 2024-03-01 19:29:17      card  ANON-0000-0000-0009   33.8
# 11 2024-03-02 10:22:06      card  ANON-0000-0000-0010   28.9
# 12 2024-03-02 10:30:35      cash         Cash Payment   40.0
# 13 2024-03-02 10:41:41      card  ANON-0000-0000-0011   33.8
# ...
